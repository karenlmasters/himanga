# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import marvin

name='8083-12704'
plate=8083
ifu=12704
vel=6844.5
rms=3*1.51e-3

img=plt.imread("Images/"+name+".png")

data = np.loadtxt("TextFiles/"+name+".txt",float)
x = data[:,0]
y = data[:,1]

plt.figure(figsize=(13,10))

plt.subplot(221)
plt.imshow(img)
plt.axis('off')

plt.subplot(222)
plt.plot(x,y,'k')
plt.plot([0,1e6],[0,0],'b')
plt.plot([vel,vel],[0,rms],'b--')
plt.xlabel("Velocity of HI (km/s)")
plt.ylabel("Flux (Jy)")
plt.xlim(vel-1000,vel+1000)
plt.title(name)


plt.show()

# %%
img=plt.imread('https://data.sdss.org/sas/mangawork/manga/spectro/redux/MPL-5/8083/stack/images/12704.png')

# %%
name='8083-3702'
vel=7148.3
rms=3*2.06e-3
data = np.loadtxt("TextFiles/"+name+".txt",float)
x = data[:,0]
y = data[:,1]
plt.plot(x,y,'k')
plt.plot([0,1e6],[0,0],'b')
plt.plot([vel,vel],[0,rms],'b--')
plt.xlabel("Velocity of HI (km/s)")
plt.ylabel("Flux (Jy)")
plt.xlim(vel-1000,vel+1000)
plt.title(name)
plt.show()
